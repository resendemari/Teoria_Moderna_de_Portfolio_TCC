# %% [markdown]
# <a href="https://colab.research.google.com/github/resendemari/Teoria_Moderna_de_Portfolio_TCC/blob/main/C%C3%B3digo_Fonte_TCC_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cnpj = ['31.713.505/0001-27','40.503.169/0001-89'] # cnpj dos fundos escolhidos
acoes = ['PRIO3.SA','PETZ3.SA','BPAC11.SA','WEGE3.SA','MGLU3.SA','VALE3.SA','ITSA3.SA'] # codigos das acoes escolhidas
rf = 0.12 # risk - free rate
a = 20   # nivel de aversao ao risco

# %%
# flag = 1: roda todos os blocos
# flag = 0: não roda os blocos de setup e de download de banco de dados

flag = 1

# %%
if (flag==1):
  # !pip install wget
  # !pip install numpy
  # !pip install yfinance

# %%
if (flag==1):
  import pandas as pd
  import wget
  from zipfile import ZipFile
  import numpy as np
  import matplotlib.pyplot as plt
  import seaborn as sns
  import math
  import scipy.optimize as sco
  from pylab import mpl
  import wget
  import yfinance as yf
  from zipfile import ZipFile
  pd.set_option("display.max_colwidth",150)

# %%
plt.style.use('seaborn-pastel')
mpl.rcParams['font.family'] = 'serif'
label_size = 18
ticks_size = 14

# %% [markdown]
# #Coletando dados do yFinance

# %% [markdown]
# #Coletando os dados da CVM

# %%
if (flag==1):
  conteudo1 = pd.DataFrame()
  meses = np.linspace(1,12,12)
  anos = np.linspace(2017,2020,4)

  for ano in anos:
    url_base = 'http://dados.cvm.gov.br/dados/FI/DOC/INF_DIARIO/DADOS/HIST/inf_diario_fi_{:02d}.zip'.format(int(ano))
    wget.download(url_base)
    arquivo_zip = 'inf_diario_fi_{:02d}.zip'.format(int(ano))
    ZipFile(arquivo_zip, 'r').extractall('CVM')
    url = '/content/CVM/inf_diario_fi_{:02d}.csv'.format(int(ano))
    for mes in meses:
      conteudo1 = pd.concat([conteudo1,pd.read_csv('/content/CVM/inf_diario_fi_{:02d}{:02d}.csv'.format(int(ano),int(mes)), sep=';')])

  anos2 = [2021]
  meses = np.linspace(1,12,12)

  for ano in anos2:
    for mes in meses:
      url_base = 'http://dados.cvm.gov.br/dados/FI/DOC/INF_DIARIO/DADOS/inf_diario_fi_{:02d}{:02d}.zip'.format(int(ano),int(mes))
      wget.download(url_base)
      arquivo_zip = 'inf_diario_fi_{:02d}{:02d}.zip'.format(int(ano),int(mes))
      ZipFile(arquivo_zip, 'r').extractall('CVM')
      url = '/content/CVM/inf_diario_fi_{:02d}{:02d}.csv'.format(int(ano),int(mes))
      conteudo1 = pd.concat([conteudo1,pd.read_csv('/content/CVM/inf_diario_fi_{:02d}{:02d}.csv'.format(int(ano),int(mes)), sep=';')])

  anos3 = [2022]
  meses = np.linspace(1,7,7)

  for ano in anos3:
    for mes in meses:
      url_base = 'http://dados.cvm.gov.br/dados/FI/DOC/INF_DIARIO/DADOS/inf_diario_fi_{:02d}{:02d}.zip'.format(int(ano),int(mes))
      wget.download(url_base)
      arquivo_zip = 'inf_diario_fi_{:02d}{:02d}.zip'.format(int(ano),int(mes))
      ZipFile(arquivo_zip, 'r').extractall('CVM')
      url = '/content/CVM/inf_diario_fi_{:02d}{:02d}.csv'.format(int(ano),int(mes))
      conteudo1 = pd.concat([conteudo1,pd.read_csv('/content/CVM/inf_diario_fi_{:02d}{:02d}.csv'.format(int(ano),int(mes)), sep=';')])

  conteudo1 = pd.DataFrame()
  meses = np.linspace(1,12,12)
  anos = np.linspace(2017,2020,4)

  for ano in anos:
    for mes in meses:
      conteudo1 = pd.concat([conteudo1,pd.read_csv('/content/CVM/inf_diario_fi_{:02d}{:02d}.csv'.format(int(ano),int(mes)), sep=';')])

  anos2 = [2021]
  meses = np.linspace(1,12,12)


  for ano in anos2:
    for mes in meses:
      conteudo1 = pd.concat([conteudo1,pd.read_csv('/content/CVM/inf_diario_fi_{:02d}{:02d}.csv'.format(int(ano),int(mes)), sep=';')])
      
  anos3 = [2022]
  meses = np.linspace(1,7,7)

  for ano in anos3:
    for mes in meses:
      conteudo1 = pd.concat([conteudo1,pd.read_csv('/content/CVM/inf_diario_fi_{:02d}{:02d}.csv'.format(int(ano),int(mes)), sep=';')])
  
flag = 0

# %%
if (flag==2):
  conteudo1 = pd.DataFrame()
  meses = np.linspace(1,12,12)
  anos = np.linspace(2017,2020,4)

  for ano in anos:
    for mes in meses:
      conteudo1 = pd.concat([conteudo1,pd.read_csv('/content/CVM/inf_diario_fi_{:02d}{:02d}.csv'.format(int(ano),int(mes)), sep=';')])

  anos2 = [2021]
  meses = np.linspace(1,12,12)

  for ano in anos2:
    for mes in meses:
      conteudo1 = pd.concat([conteudo1,pd.read_csv('/content/CVM/inf_diario_fi_{:02d}{:02d}.csv'.format(int(ano),int(mes)), sep=';')])

  anos3 = [2022]
  meses = np.linspace(1,7,7)

  for ano in anos3:
    for mes in meses:
      conteudo1 = pd.concat([conteudo1,pd.read_csv('/content/CVM/inf_diario_fi_{:02d}{:02d}.csv'.format(int(ano),int(mes)), sep=';')])

  conteudo1 = pd.DataFrame()
  meses = np.linspace(1,12,12)
  anos = np.linspace(2017,2020,4)

  for ano in anos:
    for mes in meses:
      conteudo1 = pd.concat([conteudo1,pd.read_csv('/content/CVM/inf_diario_fi_{:02d}{:02d}.csv'.format(int(ano),int(mes)), sep=';')])

  anos2 = [2021]
  meses = np.linspace(1,12,12)


  for ano in anos2:
    for mes in meses:
      conteudo1 = pd.concat([conteudo1,pd.read_csv('/content/CVM/inf_diario_fi_{:02d}{:02d}.csv'.format(int(ano),int(mes)), sep=';')])
      
  anos3 = [2022]
  meses = np.linspace(1,7,7)

  for ano in anos3:
    for mes in meses:
      conteudo1 = pd.concat([conteudo1,pd.read_csv('/content/CVM/inf_diario_fi_{:02d}{:02d}.csv'.format(int(ano),int(mes)), sep=';')])
  
flag = 0

# %% [markdown]
# ## Selecionando os fundos pelo CNPJ e pivotando a tabela para ter os fundos nas colunas

# %%
filt = conteudo1['CNPJ_FUNDO'].isin(cnpj)
fundos_escolhidos = conteudo1.loc[filt]
precos_fundos = fundos_escolhidos.pivot(index='DT_COMPTC', columns='CNPJ_FUNDO',values=['VL_QUOTA'])

# %%
carteira = pd.DataFrame()
for i in acoes:
  carteira[i] = yf.download(i, period='5y')['Adj Close']

precos_acoes = pd.DataFrame(carteira)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# #Análise de títulos

# %% [markdown]
# ## Calculando os retornos em função do preço anterior

# %%
# Estimar os retornos diários
retornos_fundos = precos_fundos.pct_change()
retornos_acoes = precos_acoes.pct_change()

# %% [markdown]
# ## Unindo os dados de ações e fundos em um dataframe

# %%
d_acoes = {}
d_fundos = {}

for i in range(len(acoes)):
  d_acoes[acoes[i]]=retornos_acoes[acoes[i]]

for i in range(len(cnpj)):
  d_fundos[cnpj[i]]=retornos_fundos['VL_QUOTA'][cnpj[i]]

if (cnpj):
  dataframe = retornos_fundos['VL_QUOTA'].index
  retornos_fundos_df = pd.DataFrame(index=np.array(dataframe),data = d_fundos)
  retornos_fundos_df.index = pd.to_datetime(retornos_fundos_df.index)
else:
  dataframe = retornos_fundos
  retornos_fundos_df = pd.DataFrame(dataframe)
  

if (acoes): 
  dataframe = retornos_acoes.index
  retornos_acoes_df = pd.DataFrame(index=np.array(dataframe),data = d_acoes)
  retornos_acoes_df.index = pd.to_datetime(retornos_acoes_df.index) 
else:
  dataframe = retornos_fundos
  retornos_acoes_df = pd.DataFrame(dataframe)

if(len(acoes) & len(cnpj)):
  retornos_df = pd.merge(retornos_acoes_df,retornos_fundos_df,left_index=True, right_index=True)
elif(not(len(cnpj)) & len(acoes)):
  retornos_df = retornos_acoes_df
elif(not(len(acoes)) & cnpj):
  retornos_df = retornos_fundos_df

# %% [markdown]
# ## Cálculo do retorno esperado, do desvio-padrão e da matriz de covariância anualizados

# %%
e_r = retornos_df.mean()   #retorno esperado
var = retornos_df.var()    #variancia
vol = var**0.5             #volatilidade = desvio-padrao
matriz_cov = retornos_df.cov()  #matriz de covariancia

e_r = e_r * 252
matriz_cov = matriz_cov * 252
vol = var*np.sqrt(252)

# %% [markdown]
# #Simulação de carteiras

# %%
noa = len(retornos_df.columns)  #numero de ativos na carteira
nop = 50000                    #numero de portfolios simulados

p_ret = []
p_vol = []
p_pesos = []

for portfolios in range(nop):
  pesos = np.random.random(noa)
  pesos = pesos/np.sum(pesos)
  p_pesos.append(pesos)
  p_ret.append(np.sum(e_r*pesos))
  p_vol.append(np.sqrt(np.dot(pesos.T,np.dot(matriz_cov,pesos))))


p_ret = np.array(p_ret)
p_vol = np.array(p_vol)
dados = {'Retorno': p_ret,'Risco':p_vol}
portfolios = pd.DataFrame(dados)
portfolios['Sharpe'] = (portfolios['Retorno']-rf)/portfolios['Risco']


min_risk = portfolios[portfolios['Risco']==portfolios['Risco'].min()]
max_sharpe = portfolios[portfolios['Sharpe']==portfolios['Sharpe'].max()]
indice_min_risk = min_risk.index.values.astype(int)[0]
indice_max_sharpe = max_sharpe.index.values.astype(int)[0]

# %% [markdown]
# ##Plot carteiras simuladas

# %%
plt.figure(figsize=(10, 6))
plt.scatter(p_vol, p_ret, c=(p_ret-rf) / p_vol, marker='o',alpha=0.8, cmap='plasma')
plt.grid(True)
plt.xlabel('Volatilidade',fontsize=label_size)
plt.ylabel('Retorno esperado',fontsize=label_size)
plt.plot(min_risk['Risco'],min_risk['Retorno'], 'go', markersize=10.0)
plt.plot(max_sharpe['Risco'],max_sharpe['Retorno'], 'co', markersize=10.0)
cb = plt.colorbar()
cb.set_label(label='Indice de Sharpe',size=label_size)
cb.ax.tick_params(labelsize=ticks_size)
plt.xticks(fontsize=ticks_size)
plt.yticks(fontsize=ticks_size)


plt.savefig('carteiras_simuladas.pdf',format='pdf',dpi=300,transparent=False,bbox_inches='tight')

# %% [markdown]
# ##Print resultados da simulação

# %%
print('\n\n-------------- Carteira Mínimo Risco -----------\n')
print('Retorno:',round(float(min_risk['Retorno']*100),2),'%')
print('Risco:',round(float(min_risk['Risco']*100),2),'%')
print('Sharpe:',round(float(min_risk['Sharpe']),2))
print('pesos: ',p_pesos[indice_min_risk])

print('\n\n-------------- Carteira Máximo Sharpe -----------\n')
print('Retorno:',round(float(max_sharpe['Retorno']*100),2),'%')
print('Risco:',round(float(max_sharpe['Risco']*100),2),'%')
print('Sharpe:',round(float(max_sharpe['Sharpe']),2))
print('pesos: ',p_pesos[indice_max_sharpe])
# Out:
# -------------- Carteira Mínimo Risco -----------
#
# Retorno: 19.31 %
# Risco: 20.64 %
# Sharpe: 0.35
# pesos:  [0.00236733 0.07475069 0.09222121 0.09433778 0.01740855 0.13771343
#  0.3548737  0.07170584 0.15462148]
#
#
# -------------- Carteira Máximo Sharpe -----------
#
# Retorno: 52.07 %
# Risco: 27.58 %
# Sharpe: 1.45
# pesos:  [2.29183376e-01 5.62055788e-03 1.82517738e-01 5.70382979e-02
#  2.40410819e-04 2.67802187e-01 5.17828511e-02 1.47590465e-01
#  5.82241165e-02]

# %% [markdown]
# #Otimização

# %%
#Definindo funcoes para calcular a minima variancia e o maximo indice de sharpe 

def statistics(pesos):
  pesos = np.array(pesos)
  pret = np.sum(e_r*pesos)
  pvol = math.sqrt(np.dot(pesos.T,np.dot(matriz_cov,pesos)))
  return np.array([pret,pvol,(pret-rf)/pvol])

def min_func_variance(pesos):
  return statistics(pesos)[1]**2
  #return statistics(pesos)[1]

def max_func_sharpe(pesos):
  return -statistics(pesos)[2]

def min_func_port(pesos):
  return statistics(pesos)[1]


pesos_i = np.array(noa*[1/noa,]) #condicao inicial
bnds = tuple((0, 1) for x in range(noa)) #limites
cons =  ({'type':'eq','fun':lambda x:np.sum(x)-1}) #restricao


otim_vol = sco.minimize(min_func_variance,pesos_i,method='SLSQP',bounds=bnds,constraints=cons)
otim_sharpe = sco.minimize(max_func_sharpe,pesos_i,method='SLSQP',bounds=bnds,constraints=cons)

# %% [markdown]
# ##Print resultados da otimização

# %%
print('\n\n-------------- Carteira Mínimo Risco Global -----------\n')

print('Retorno:',round(statistics(otim_vol['x'])[0]*100,2),'%')
print('Risco:',round(statistics(otim_vol['x'])[1]*100,2),'%')
print('Sharpe:',statistics(otim_vol['x']).round(2)[2])
print('Pesos da carteira com minima volatilidade: ',otim_vol['x'].round(3))

print('\n\n-------------- Carteira Máximo Sharpe -----------\n')

print('Retorno:',round(statistics(otim_sharpe['x'])[0]*100,2),'%')
print('Risco:',round(statistics(otim_sharpe['x'])[1]*100,2),'%')
print('Sharpe:',statistics(otim_sharpe['x']).round(2)[2])
print('Pesos da carteira com maximo sharpe: ',otim_sharpe['x'].round(3))
# Out:
# -------------- Carteira Mínimo Risco Global -----------
#
# Retorno: 16.71 %
# Risco: 19.57 %
# Sharpe: 0.24
# Pesos da carteira com minima volatilidade:  [0.    0.059 0.    0.122 0.002 0.184 0.485 0.067 0.081]
#
#
# -------------- Carteira Máximo Sharpe -----------
#
# Retorno: 70.54 %
# Risco: 36.69 %
# Sharpe: 1.6
# Pesos da carteira com maximo sharpe:  [0.467 0.    0.219 0.    0.    0.177 0.    0.137 0.   ]

# %% [markdown]
# ##Fronteira de Mínima Variância

# %%
def min_func_ret(pesos):
  return statistics(pesos)[0]

def max_func_ret(pesos):
  return -statistics(pesos)[0]

min_ret = sco.minimize(min_func_ret,pesos_i,method='SLSQP',bounds=bnds,constraints=cons)
max_ret = sco.minimize(max_func_ret,pesos_i,method='SLSQP',bounds=bnds,constraints=cons)

pesos_i = np.array(noa*[1/noa,]) #condicao inicial
bnds = tuple((0, 1) for x in range(noa)) #limites
cons =  ({'type':'eq','fun':lambda x: statistics(x)[0]-tret},
         {'type':'eq','fun':lambda x:np.sum(x)-1}) #restricoes


trets = np.linspace(min_ret['fun'],-max_ret['fun'],50)
tvols=[]

for tret in trets:
  res = sco.minimize(min_func_port,pesos_i,method='SLSQP',bounds=bnds,constraints=cons)
  tvols.append(res['fun'])

tvols = np.array(tvols)

# %% [markdown]
# ##Plot Fronteira de Mínima Variância

# %%
plt.figure(figsize=(10, 6))
plt.grid(True)
plt.scatter(p_vol, p_ret, c=(p_ret-rf) / p_vol, marker='o',alpha=0.8, cmap='plasma')
plt.scatter(tvols, trets,c= (trets-rf)/ tvols, marker='x',alpha=0.8, cmap='plasma')
plt.xlabel('Volatilidade',fontsize=label_size)
plt.ylabel('Retorno esperado',fontsize=label_size)
plt.plot(min_risk['Risco'],min_risk['Retorno'], 'go', markersize=10.0)
plt.plot(max_sharpe['Risco'],max_sharpe['Retorno'], 'co', markersize=10.0)
plt.plot(statistics(otim_sharpe['x'])[1], statistics(otim_sharpe['x'])[0],'y*',markersize=20.0)
plt.plot(statistics(otim_vol['x'])[1], statistics(otim_vol['x'])[0], 'm*',markersize=20.0)
cb = plt.colorbar()
cb.set_label(label='Indice de Sharpe',size=label_size)
cb.ax.tick_params(labelsize=ticks_size)
plt.xticks(fontsize=ticks_size)
plt.yticks(fontsize=ticks_size)

plt.savefig('fronteira_minima_variancia.pdf',format='pdf',dpi=300,transparent=False,bbox_inches='tight')

# %% [markdown]
# ##Fronteira Eficiente

# %%
ind = np.argmin(tvols)
evols = tvols[ind:]
erets = trets[ind:]

# %% [markdown]
# ##Plot Fronteira Eficiente

# %%
plt.figure(figsize=(10, 6))
plt.scatter(p_vol, p_ret, c=(p_ret-rf) / p_vol, marker='o',alpha=0.8, cmap='plasma')
plt.grid(True)
plt.scatter(tvols, trets,c= (trets-rf)/ tvols, marker='x',alpha=0.8, cmap='plasma')
plt.xlabel('Volatilidade',fontsize=label_size)
plt.ylabel('Retorno esperado',fontsize=label_size)
plt.plot(min_risk['Risco'],min_risk['Retorno'], 'go', markersize=10.0)
plt.plot(max_sharpe['Risco'],max_sharpe['Retorno'], 'co', markersize=10.0)
plt.plot(statistics(otim_sharpe['x'])[1], statistics(otim_sharpe['x'])[0],'y*',markersize=20.0)
plt.plot(statistics(otim_vol['x'])[1], statistics(otim_vol['x'])[0], 'm*',markersize=20.0)
plt.plot(evols,erets,'b',lw=2.0)
plt.axhline(0, color='k', ls='--', lw=2.0)
plt.axvline(0, color='k', ls='--', lw=2.0)
plt.grid(visible=True, which='both', axis='both')
cb = plt.colorbar()
cb.set_label(label='Indice de Sharpe',size=label_size)
cb.ax.tick_params(labelsize=ticks_size)
plt.xticks(fontsize=ticks_size)
plt.yticks(fontsize=ticks_size)


plt.savefig('fronteira_eficiente.pdf',format='pdf',dpi=300,transparent=False,bbox_inches='tight')

# %% [markdown]
# ## Linha de Alocação de Capital

# %%
eixo_x = []
eixo_y = []

for er in np.linspace(rf,max(trets),100):
  sd = (er - rf)/((statistics(otim_sharpe['x'])[0]-rf)/statistics(otim_sharpe['x'])[1])
  eixo_x.append(sd)
  eixo_y.append(er)

# %% [markdown]
# ##Plot Linha de Alocação de Capital

# %%
plt.figure(figsize=(10, 6))
plt.scatter(p_vol, p_ret, c=(p_ret-rf) / p_vol, marker='o',alpha=0.8, cmap='plasma') 
plt.grid(True)
plt.scatter(tvols, trets,c= (trets-rf)/ tvols, marker='x',alpha=0.8, cmap='plasma')
plt.xlabel('Volatilidade',fontsize=label_size)
plt.ylabel('Retorno esperado',fontsize=label_size)
plt.plot(min_risk['Risco'],min_risk['Retorno'], 'go', markersize=10.0)
plt.plot(max_sharpe['Risco'],max_sharpe['Retorno'], 'co', markersize=10.0)
plt.plot(statistics(otim_sharpe['x'])[1], statistics(otim_sharpe['x'])[0],'y*',markersize=20.0)
plt.plot(statistics(otim_vol['x'])[1], statistics(otim_vol['x'])[0], 'm*',markersize=20.0)
plt.plot(evols,erets,'b',lw=2.0)
plt.axhline(0, color='k', ls='--', lw=2.0)
plt.axvline(0, color='k', ls='--', lw=2.0)
plt.plot(eixo_x,eixo_y)
plt.grid(visible=True, which='both', axis='both')
cb = plt.colorbar()
cb.set_label(label='Indice de Sharpe',size=label_size)
cb.ax.tick_params(labelsize=ticks_size)
plt.xticks(fontsize=ticks_size)
plt.yticks(fontsize=ticks_size)

plt.savefig('linha_de_alocacao_de_capital.pdf',format='pdf',dpi=300,transparent=False,bbox_inches='tight')

# %% [markdown]
# #Seleção de carteiras

# %%
wp = (statistics(otim_sharpe['x'])[0]-rf)/(a*(statistics(otim_sharpe['x'])[1])**2)
r_oc = wp*statistics(otim_sharpe['x'])[0]+(1-wp)*rf
v_oc = wp*statistics(otim_sharpe['x'])[1]

if(v_oc < 0):
  v_oc = 0
  r_oc = rf

if(r_oc > statistics(otim_sharpe['x'])[0]):
  r_oc = statistics(otim_sharpe['x'])[0]
  v_oc = statistics(otim_sharpe['x'])[1]

# %% [markdown]
# ##Plot carteira completa

# %%
plt.figure(figsize=(10, 6))
plt.scatter(p_vol, p_ret, c=(p_ret-rf) / p_vol, marker='o',alpha=0.8, cmap='plasma')
plt.grid(True)
plt.scatter(tvols, trets,c= (trets-rf)/ tvols, marker='x',alpha=0.8, cmap='plasma')
plt.xlabel('Volatilidade',fontsize=label_size)
plt.ylabel('Retorno esperado',fontsize=label_size)
plt.plot(min_risk['Risco'],min_risk['Retorno'], 'go', markersize=10.0)
plt.plot(max_sharpe['Risco'],max_sharpe['Retorno'], 'co', markersize=10.0)
plt.plot(statistics(otim_sharpe['x'])[1], statistics(otim_sharpe['x'])[0],'y*',markersize=20.0)
plt.plot(statistics(otim_vol['x'])[1], statistics(otim_vol['x'])[0], 'm*',markersize=20.0)
plt.plot(evols,erets,'b',lw=2.0)
plt.axhline(0, color='k', ls='--', lw=2.0)
plt.axvline(0, color='k', ls='--', lw=2.0)
plt.plot(eixo_x,eixo_y)
plt.grid(visible=True, which='both', axis='both')
plt.plot(v_oc,r_oc,marker = '*',color = 'purple',markersize=15.0)
cb = plt.colorbar()
cb.set_label(label='Indice de Sharpe',size=label_size)
cb.ax.tick_params(labelsize=ticks_size)
plt.xticks(fontsize=ticks_size)
plt.yticks(fontsize=ticks_size)

plt.savefig('carteira_final.pdf',format='pdf',dpi=300,transparent=False,bbox_inches='tight')

# %% [markdown]
# ##Print resultados

# %%
print('\n\n-------------- Carteira Completa -----------\n')
print('Risco:',round(v_oc*100,2),'%')
print('Retorno:',round(r_oc*100,2),'%')
print('Premio de risco:',round((r_oc-rf)*100,2),'%')
print('Dado o nivel de aversão ao risco do investidor:',a)
print('Porcentagem a ser alocada no ativo isento de risco:',round(100-wp*100,2),'%')
print('Porcentagem a ser alocada na carteira de risco:',round(wp*100,2),'%')
print('\n')
print('\nPorcentagem a ser alocada em cada ativo de risco:\n')
soma = 0
for i in range(len(retornos_df.columns)):
  print('Ativo:',retornos_df.columns[i],' - Peso:',round(otim_sharpe['x'][i]*100,2),'%')
  soma = soma + round(otim_sharpe['x'][i]*100,2)
print('\nSoma pesos ativos de risco:',round(soma,2),'%')
print('\n')
print('------------ Carteira de Risco -------------\n')
print('Risco da carteira de risco com maior Sharpe:',round(statistics(otim_sharpe['x'])[1]*100,2),'%')
print('Retorno da carteira de risco com maior Sharpe:',round(statistics(otim_sharpe['x'])[0]*100,2),'%')
print('Índice de Sharpe da carteira de risco ótima:', round((statistics(otim_sharpe['x'])[0]-rf)/statistics(otim_sharpe['x'])[1],3))
print('\nPorcentagem a ser alocada em cada ativo de risco:\n')
soma = 0
for i in range(len(retornos_df.columns)):
  print('Ativo:',retornos_df.columns[i],' - Peso:',round(otim_sharpe['x'][i]*wp*100,2),'%')
  soma = soma + round(otim_sharpe['x'][i]*wp*100,2)
print('\nSoma pesos ativos de risco:',round(soma,2),'%')
# Out:
# -------------- Carteira Completa -----------
#
# Risco: 7.98 %
# Retorno: 24.73 %
# Premio de risco: 12.73 %
# Dado o nivel de aversão ao risco do investidor: 20
# Porcentagem a ser alocada no ativo isento de risco: 78.25 %
# Porcentagem a ser alocada na carteira de risco: 21.75 %
#
#
#
# Porcentagem a ser alocada em cada ativo de risco:
#
# Ativo: PRIO3.SA  - Peso: 46.73 %
# Ativo: PETZ3.SA  - Peso: 0.0 %
# Ativo: BPAC11.SA  - Peso: 21.91 %
# Ativo: WEGE3.SA  - Peso: 0.0 %
# Ativo: MGLU3.SA  - Peso: 0.0 %
# Ativo: VALE3.SA  - Peso: 17.68 %
# Ativo: ITSA3.SA  - Peso: 0.0 %
# Ativo: 31.713.505/0001-27  - Peso: 13.69 %
# Ativo: 40.503.169/0001-89  - Peso: 0.0 %
#
# Soma pesos ativos de risco: 100.01 %
#
#
# ------------ Carteira de Risco -------------
#
# Risco da carteira de risco com maior Sharpe: 36.69 %
# Retorno da carteira de risco com maior Sharpe: 70.54 %
# Índice de Sharpe da carteira de risco ótima: 1.596
#
# Porcentagem a ser alocada em cada ativo de risco:
#
# ...

# %% [markdown]
# #Limites de Alocação

# %% [markdown]
# ##Definindo limites de alocação para cada ativo (bounds)

# %%
limite_w_acoes = (0.01,0.15)
limite_w_fundos = (0.02,0.25)

dict_ativos = {}
dict_acoes = {}
dict_fundos = {}
ativos = np.array(acoes+cnpj)

if((len(acoes)) & len(cnpj)):

  for i in range(len(acoes)):
    dict_ativos[i]=[acoes[i],'acao']
  for j in range(i+1,len(ativos)):
    dict_ativos[j]=[cnpj[j-len(acoes)],'fundo']

elif(not(len(acoes))):
    for i in range(len(cnpj)):
      dict_ativos[i]=[cnpj[i],'fundo']

elif(not(len(cnpj))):
    for i in range(len(acoes)):
      dict_ativos[i]=[acoes[i],'acao']

limites = []
for i in dict_ativos:
  if(dict_ativos[i][1] == 'acao'):
    limites.append(limite_w_acoes)
  elif(dict_ativos[i][1] == 'fundo'):
    limites.append(limite_w_fundos)

bnds = tuple(limites)

# %% [markdown]
# ##Otimização com limites de alocação

# %%
pesos_i = np.array(noa*[1/noa,]) #condicao inicial
cons =  ({'type':'eq','fun':lambda x:np.sum(x)-1}) #restricao

otim_vol_l = sco.minimize(min_func_variance,pesos_i,method='SLSQP',bounds=bnds,constraints=cons)
otim_sharpe_l = sco.minimize(max_func_sharpe,pesos_i,method='SLSQP',bounds=bnds,constraints=cons)

print('\n\n-------------- Carteira Máximo Sharpe -----------\n')
print('Retorno:',round(statistics(otim_sharpe_l['x'])[0]*100,2),'%')
print('Risco:',round(statistics(otim_sharpe_l['x'])[1]*100,2),'%')
print('Sharpe:',statistics(otim_sharpe_l['x']).round(2)[2])
print('Pesos da carteira com maximo sharpe: ',otim_sharpe_l['x'].round(3))
# Out:
# -------------- Carteira Máximo Sharpe -----------
#
# Retorno: 45.26 %
# Risco: 26.92 %
# Sharpe: 1.24
# Pesos da carteira com maximo sharpe:  [0.15  0.01  0.15  0.15  0.01  0.15  0.01  0.206 0.164]
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/optimize.py:283: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   "minimize step, clipping to bounds", RuntimeWarning)

# %% [markdown]
# ## Plot carteira de risco com restrições de alocação

# %%
plt.figure(figsize=(10, 6))
plt.grid(True)
plt.scatter(p_vol, p_ret, c=(p_ret-rf) / p_vol, marker='o',alpha=0.8, cmap='plasma')
plt.scatter(tvols, trets,c= (trets-rf)/ tvols, marker='x',alpha=0.8, cmap='plasma')
plt.xlabel('Volatilidade',fontsize=label_size)
plt.ylabel('Retorno esperado',fontsize=label_size)
plt.plot(min_risk['Risco'],min_risk['Retorno'], 'go', markersize=10.0)
plt.plot(max_sharpe['Risco'],max_sharpe['Retorno'], 'co', markersize=10.0)
plt.plot(statistics(otim_sharpe['x'])[1], statistics(otim_sharpe['x'])[0],'y*',markersize=20.0)
plt.plot(statistics(otim_vol['x'])[1], statistics(otim_vol['x'])[0], 'm*',markersize=20.0)
plt.plot(statistics(otim_sharpe_l['x'])[1], statistics(otim_sharpe_l['x'])[0],marker = 's',color = 'blue',markersize=10.0)

cb = plt.colorbar()
cb.set_label(label='Indice de Sharpe',size=label_size)
cb.ax.tick_params(labelsize=ticks_size)
plt.xticks(fontsize=ticks_size)
plt.yticks(fontsize=ticks_size)

plt.savefig('carteira_otima_nova.pdf',format='pdf',dpi=300,transparent=False,bbox_inches='tight')

# %% [markdown]
# ## Linha de Alocação de Capital com restrições

# %%
eixo_x = []
eixo_y = []

for er in np.linspace(rf,max(trets),100):
  sd = (er - rf)/((statistics(otim_sharpe_l['x'])[0]-rf)/statistics(otim_sharpe_l['x'])[1])
  eixo_x.append(sd)
  eixo_y.append(er)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(p_vol, p_ret, c=(p_ret-rf) / p_vol, marker='o',alpha=0.8, cmap='plasma') 
plt.grid(True)
plt.scatter(tvols, trets,c= (trets-rf)/ tvols, marker='x',alpha=0.8, cmap='plasma')
plt.xlabel('Volatilidade',fontsize=label_size)
plt.ylabel('Retorno esperado',fontsize=label_size)
plt.plot(min_risk['Risco'],min_risk['Retorno'], 'go', markersize=10.0)
plt.plot(max_sharpe['Risco'],max_sharpe['Retorno'], 'co', markersize=10.0)
plt.plot(statistics(otim_sharpe['x'])[1], statistics(otim_sharpe['x'])[0],'y*',markersize=20.0)
plt.plot(statistics(otim_vol['x'])[1], statistics(otim_vol['x'])[0], 'm*',markersize=20.0)
plt.plot(statistics(otim_sharpe_l['x'])[1], statistics(otim_sharpe_l['x'])[0],marker = 's',color = 'blue',markersize=10.0)
plt.plot(evols,erets,'b',lw=2.0)
plt.axhline(0, color='k', ls='--', lw=2.0)
plt.axvline(0, color='k', ls='--', lw=2.0)
plt.plot(eixo_x,eixo_y)
plt.grid(visible=True, which='both', axis='both')

cb = plt.colorbar()
cb.set_label(label='Indice de Sharpe',size=label_size)
cb.ax.tick_params(labelsize=ticks_size)
plt.xticks(fontsize=ticks_size)
plt.yticks(fontsize=ticks_size)

plt.savefig('cal_nova.pdf',format='pdf',dpi=300,transparent=False,bbox_inches='tight')

# %% [markdown]
# ##Seleção de carteiras com restrições

# %%
wp = (statistics(otim_sharpe_l['x'])[0]-rf)/(a*(statistics(otim_sharpe_l['x'])[1])**2)
r_oc = wp*statistics(otim_sharpe_l['x'])[0]+(1-wp)*rf
v_oc = wp*statistics(otim_sharpe_l['x'])[1]

if(v_oc < 0):
  v_oc = 0
  r_oc = rf

if(r_oc > statistics(otim_sharpe_l['x'])[0]):
  r_oc = statistics(otim_sharpe_l['x'])[0]
  v_oc = statistics(otim_sharpe_l['x'])[1]

# %% [markdown]
# ##Plot carteira completa com restrições

# %%
plt.figure(figsize=(10, 6))
plt.scatter(p_vol, p_ret, c=(p_ret-rf) / p_vol, marker='o',alpha=0.8, cmap='plasma') #viridis, plasma, magma
plt.grid(True)
plt.scatter(tvols, trets,c= (trets-rf)/ tvols, marker='x',alpha=0.8, cmap='plasma')
plt.xlabel('Volatilidade',fontsize=label_size)
plt.ylabel('Retorno esperado',fontsize=label_size)
plt.plot(min_risk['Risco'],min_risk['Retorno'], 'go', markersize=10.0)
plt.plot(max_sharpe['Risco'],max_sharpe['Retorno'], 'co', markersize=10.0)
plt.plot(statistics(otim_sharpe['x'])[1], statistics(otim_sharpe['x'])[0],'y*',markersize=20.0)
plt.plot(statistics(otim_vol['x'])[1], statistics(otim_vol['x'])[0], 'm*',markersize=20.0)
plt.plot(statistics(otim_sharpe_l['x'])[1], statistics(otim_sharpe_l['x'])[0],marker = 's',color = 'blue',markersize=10.0)
plt.plot(evols,erets,'b',lw=2.0)
plt.axhline(0, color='k', ls='--', lw=2.0)
plt.axvline(0, color='k', ls='--', lw=2.0)
plt.plot(eixo_x,eixo_y)
plt.grid(visible=True, which='both', axis='both')
plt.plot(v_oc,r_oc,marker = 's',color = 'purple',markersize=10.0)
cb = plt.colorbar()
cb.set_label(label='Indice de Sharpe',size=label_size)
cb.ax.tick_params(labelsize=ticks_size)
plt.xticks(fontsize=ticks_size)
plt.yticks(fontsize=ticks_size)

plt.savefig('carteira_final_nova.pdf',format='pdf',dpi=300,transparent=False,bbox_inches='tight')

# %% [markdown]
# ##Print resultados carteira completa com restrições

# %%
print('\n\n-------------- Carteira Completa -----------\n')
print('Risco:',round(v_oc*100,2),'%')
print('Retorno:',round(r_oc*100,2),'%')
print('Premio de risco:',round((r_oc-rf)*100,2),'%')
print('Dado o nivel de aversão ao risco do investidor:',a)
print('Porcentagem a ser alocada no ativo isento de risco:',round(100-wp*100,2),'%')
print('Porcentagem a ser alocada na carteira de risco:',round(wp*100,2),'%')
print('\n')
print('\nPorcentagem a ser alocada em cada ativo de risco:\n')
soma = 0
for i in range(len(retornos_df.columns)):
  print('Ativo:',retornos_df.columns[i],' - Peso:',round(otim_sharpe_l['x'][i]*100,2),'%')
  soma = soma + round(otim_sharpe_l['x'][i]*100,2)
print('\nSoma pesos ativos de risco:',round(soma,2),'%')
print('\n')
print('------------ Carteira de Risco -------------\n')
print('Risco da carteira de risco com maior Sharpe:',round(statistics(otim_sharpe_l['x'])[1]*100,2),'%')
print('Retorno da carteira de risco com maior Sharpe:',round(statistics(otim_sharpe_l['x'])[0]*100,2),'%')
print('Índice de Sharpe da carteira de risco ótima:', round((statistics(otim_sharpe_l['x'])[0]-rf)/statistics(otim_sharpe_l['x'])[1],3))
print('\nPorcentagem a ser alocada em cada ativo de risco:\n')
soma = 0
for i in range(len(retornos_df.columns)):
  print('Ativo:',retornos_df.columns[i],' - Peso:',round(otim_sharpe_l['x'][i]*wp*100,2),'%')
  soma = soma + round(otim_sharpe_l['x'][i]*wp*100,2)
print('\nSoma pesos ativos de risco:',round(soma,2),'%')
# Out:
# -------------- Carteira Completa -----------
#
# Risco: 6.18 %
# Retorno: 19.63 %
# Premio de risco: 7.63 %
# Dado o nivel de aversão ao risco do investidor: 20
# Porcentagem a ser alocada no ativo isento de risco: 77.05 %
# Porcentagem a ser alocada na carteira de risco: 22.95 %
#
#
#
# Porcentagem a ser alocada em cada ativo de risco:
#
# Ativo: PRIO3.SA  - Peso: 15.0 %
# Ativo: PETZ3.SA  - Peso: 1.0 %
# Ativo: BPAC11.SA  - Peso: 15.0 %
# Ativo: WEGE3.SA  - Peso: 15.0 %
# Ativo: MGLU3.SA  - Peso: 1.0 %
# Ativo: VALE3.SA  - Peso: 15.0 %
# Ativo: ITSA3.SA  - Peso: 1.0 %
# Ativo: 31.713.505/0001-27  - Peso: 20.63 %
# Ativo: 40.503.169/0001-89  - Peso: 16.37 %
#
# Soma pesos ativos de risco: 100.0 %
#
#
# ------------ Carteira de Risco -------------
#
# Risco da carteira de risco com maior Sharpe: 26.92 %
# Retorno da carteira de risco com maior Sharpe: 45.26 %
# Índice de Sharpe da carteira de risco ótima: 1.236
#
# Porcentagem a ser alocada em cada ativo de risco:
#
# ...
